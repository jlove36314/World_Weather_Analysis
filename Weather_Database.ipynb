# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]   
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | husavik
# Processing Record 3 of Set 1 | santa cruz de la palma
# Processing Record 4 of Set 1 | nemuro
# Processing Record 5 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 1 | shimoda
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | kidal
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | kachikau
# City not found. Skipping...
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | te anau
# Processing Record 16 of Set 1 | cidreira
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | bathsheba
# Processing Record 22 of Set 1 | nichinan
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | bonavista
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | pak chong
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | monywa
# Processing Record 29 of Set 1 | gazanjyk
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | mareeba
# Processing Record 32 of Set 1 | ambilobe
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 1 | bengkulu
# Processing Record 37 of Set 1 | ziarat
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | ponta delgada
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | praya
# Processing Record 42 of Set 1 | ladnun
# Processing Record 43 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 1 | pimenta bueno
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | guanica
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | ocos
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | pangnirtung
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | inhambane
# Processing Record 7 of Set 2 | hualmay
# Processing Record 8 of Set 2 | mount pleasant
# Processing Record 9 of Set 2 | ampanihy
# Processing Record 10 of Set 2 | sechura
# Processing Record 11 of Set 2 | norman wells
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | mkushi
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | pisco
# Processing Record 16 of Set 2 | chavakkad
# Processing Record 17 of Set 2 | fort nelson
# Processing Record 18 of Set 2 | iwanai
# Processing Record 19 of Set 2 | henderson
# Processing Record 20 of Set 2 | la rioja
# Processing Record 21 of Set 2 | saint-marc
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | thompson
# Processing Record 24 of Set 2 | faanui
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | vostok
# Processing Record 27 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | chulman
# Processing Record 30 of Set 2 | artyom
# Processing Record 31 of Set 2 | smidovich
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | acapulco
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | borama
# City not found. Skipping...
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | cairns
# Processing Record 38 of Set 2 | istanbul
# Processing Record 39 of Set 2 | den helder
# Processing Record 40 of Set 2 | ancud
# Processing Record 41 of Set 2 | puerto ayacucho
# Processing Record 42 of Set 2 | iquitos
# Processing Record 43 of Set 2 | hayden
# Processing Record 44 of Set 2 | bilibino
# Processing Record 45 of Set 2 | ye
# City not found. Skipping...
# Processing Record 46 of Set 2 | portland
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | saint-pierre
# Processing Record 49 of Set 2 | puerto del rosario
# Processing Record 50 of Set 2 | rawson
# Processing Record 1 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 3 | yar-sale
# Processing Record 3 of Set 3 | san isidro
# Processing Record 4 of Set 3 | vallenar
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | carrickmacross
# Processing Record 7 of Set 3 | nuuk
# Processing Record 8 of Set 3 | hvammstangi
# City not found. Skipping...
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | kedrovyy
# Processing Record 12 of Set 3 | okhotsk
# Processing Record 13 of Set 3 | mount isa
# Processing Record 14 of Set 3 | kamaishi
# Processing Record 15 of Set 3 | nantucket
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | isiro
# Processing Record 19 of Set 3 | matagami
# Processing Record 20 of Set 3 | hithadhoo
# Processing Record 21 of Set 3 | sisimiut
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | gainesville
# Processing Record 24 of Set 3 | saldanha
# Processing Record 25 of Set 3 | betare oya
# Processing Record 26 of Set 3 | keti bandar
# Processing Record 27 of Set 3 | agirish
# Processing Record 28 of Set 3 | koboko
# Processing Record 29 of Set 3 | sibolga
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | clara
# Processing Record 32 of Set 3 | sur
# Processing Record 33 of Set 3 | vaini
# Processing Record 34 of Set 3 | cherskiy
# Processing Record 35 of Set 3 | eureka
# Processing Record 36 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 3 | butterworth
# Processing Record 38 of Set 3 | sioux lookout
# Processing Record 39 of Set 3 | batagay
# Processing Record 40 of Set 3 | belaya gora
# Processing Record 41 of Set 3 | mao
# Processing Record 42 of Set 3 | anadyr
# Processing Record 43 of Set 3 | albany
# Processing Record 44 of Set 3 | carman
# Processing Record 45 of Set 3 | payyannur
# Processing Record 46 of Set 3 | bunia
# Processing Record 47 of Set 3 | vilhena
# Processing Record 48 of Set 3 | mehriz
# Processing Record 49 of Set 3 | khipro
# Processing Record 50 of Set 3 | san quintin
# Processing Record 1 of Set 4 | hobart
# Processing Record 2 of Set 4 | caravelas
# Processing Record 3 of Set 4 | heinola
# Processing Record 4 of Set 4 | santa cruz
# Processing Record 5 of Set 4 | wajima
# Processing Record 6 of Set 4 | bontang
# Processing Record 7 of Set 4 | victoria
# Processing Record 8 of Set 4 | blois
# Processing Record 9 of Set 4 | aden
# Processing Record 10 of Set 4 | sao filipe
# Processing Record 11 of Set 4 | kruisfontein
# Processing Record 12 of Set 4 | pochutla
# Processing Record 13 of Set 4 | fortuna
# Processing Record 14 of Set 4 | san cristobal
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | clyde river
# Processing Record 17 of Set 4 | arraial do cabo
# Processing Record 18 of Set 4 | verkhnyaya toyma
# Processing Record 19 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 4 | aswan
# Processing Record 21 of Set 4 | holoby
# Processing Record 22 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 4 | provideniya
# Processing Record 24 of Set 4 | omboue
# Processing Record 25 of Set 4 | duobao
# Processing Record 26 of Set 4 | novikovo
# Processing Record 27 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 4 | minab
# Processing Record 29 of Set 4 | singaraja
# Processing Record 30 of Set 4 | aki
# Processing Record 31 of Set 4 | namibe
# Processing Record 32 of Set 4 | salalah
# Processing Record 33 of Set 4 | wete
# Processing Record 34 of Set 4 | laiagam
# City not found. Skipping...
# Processing Record 35 of Set 4 | ewa beach
# Processing Record 36 of Set 4 | auki
# Processing Record 37 of Set 4 | sobolevo
# Processing Record 38 of Set 4 | doha
# Processing Record 39 of Set 4 | zemio
# Processing Record 40 of Set 4 | tura
# Processing Record 41 of Set 4 | kamenka
# Processing Record 42 of Set 4 | beni suef
# Processing Record 43 of Set 4 | kirakira
# Processing Record 44 of Set 4 | napier
# Processing Record 45 of Set 4 | ellensburg
# Processing Record 46 of Set 4 | mabaruma
# Processing Record 47 of Set 4 | lavrentiya
# Processing Record 48 of Set 4 | san juan
# Processing Record 49 of Set 4 | hauterive
# Processing Record 50 of Set 4 | viedma
# Processing Record 1 of Set 5 | calama
# Processing Record 2 of Set 5 | dunedin
# Processing Record 3 of Set 5 | pittsfield
# Processing Record 4 of Set 5 | marawi
# Processing Record 5 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 6 of Set 5 | valparaiso
# Processing Record 7 of Set 5 | itarema
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | lanzhou
# Processing Record 10 of Set 5 | poya
# Processing Record 11 of Set 5 | abu samrah
# Processing Record 12 of Set 5 | nelson bay
# Processing Record 13 of Set 5 | pafos
# Processing Record 14 of Set 5 | senanga
# Processing Record 15 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 5 | vanavara
# Processing Record 17 of Set 5 | marly
# Processing Record 18 of Set 5 | rockhampton
# Processing Record 19 of Set 5 | ovre ardal
# Processing Record 20 of Set 5 | antofagasta
# Processing Record 21 of Set 5 | port hardy
# Processing Record 22 of Set 5 | pevek
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | usinsk
# Processing Record 25 of Set 5 | khatanga
# Processing Record 26 of Set 5 | cabo san lucas
# Processing Record 27 of Set 5 | dongsheng
# Processing Record 28 of Set 5 | banepa
# Processing Record 29 of Set 5 | roccastrada
# Processing Record 30 of Set 5 | yeniseysk
# Processing Record 31 of Set 5 | nizhniy kuranakh
# Processing Record 32 of Set 5 | svetlaya
# Processing Record 33 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 5 | mar del plata
# Processing Record 35 of Set 5 | grand gaube
# Processing Record 36 of Set 5 | hami
# Processing Record 37 of Set 5 | otavi
# Processing Record 38 of Set 5 | hienghene
# Processing Record 39 of Set 5 | acarau
# Processing Record 40 of Set 5 | puerto de la cruz
# Processing Record 41 of Set 5 | wejherowo
# Processing Record 42 of Set 5 | matara
# Processing Record 43 of Set 5 | matamoros
# Processing Record 44 of Set 5 | kharp
# Processing Record 45 of Set 5 | margate
# Processing Record 46 of Set 5 | whitehorse
# Processing Record 47 of Set 5 | anamur
# Processing Record 48 of Set 5 | sinnamary
# Processing Record 49 of Set 5 | teahupoo
# Processing Record 50 of Set 5 | bilma
# Processing Record 1 of Set 6 | codrington
# Processing Record 2 of Set 6 | guerrero negro
# Processing Record 3 of Set 6 | muravlenko
# Processing Record 4 of Set 6 | hutchinson
# Processing Record 5 of Set 6 | chunoyar
# Processing Record 6 of Set 6 | kushima
# Processing Record 7 of Set 6 | jimma
# Processing Record 8 of Set 6 | letlhakane
# Processing Record 9 of Set 6 | hay river
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | saint-joseph
# Processing Record 12 of Set 6 | broome
# Processing Record 13 of Set 6 | lompoc
# Processing Record 14 of Set 6 | nouadhibou
# Processing Record 15 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 6 | cobourg
# Processing Record 17 of Set 6 | asau
# Processing Record 18 of Set 6 | nikolayevka
# Processing Record 19 of Set 6 | gore
# Processing Record 20 of Set 6 | sanarate
# Processing Record 21 of Set 6 | san patricio
# Processing Record 22 of Set 6 | sarlat-la-caneda
# Processing Record 23 of Set 6 | chokurdakh
# Processing Record 24 of Set 6 | nemencine
# Processing Record 25 of Set 6 | alekseyevsk
# Processing Record 26 of Set 6 | madimba
# Processing Record 27 of Set 6 | isangel
# Processing Record 28 of Set 6 | kavieng
# Processing Record 29 of Set 6 | haverfordwest
# Processing Record 30 of Set 6 | arvika
# Processing Record 31 of Set 6 | tucurui
# Processing Record 32 of Set 6 | oyem
# Processing Record 33 of Set 6 | hasaki
# Processing Record 34 of Set 6 | tizimin
# Processing Record 35 of Set 6 | san vicente
# Processing Record 36 of Set 6 | bambous virieux
# Processing Record 37 of Set 6 | along
# Processing Record 38 of Set 6 | nikolskoye
# Processing Record 39 of Set 6 | papayal
# Processing Record 40 of Set 6 | bintulu
# Processing Record 41 of Set 6 | byron bay
# Processing Record 42 of Set 6 | saint george
# Processing Record 43 of Set 6 | bud
# Processing Record 44 of Set 6 | baijiantan
# Processing Record 45 of Set 6 | impfondo
# Processing Record 46 of Set 6 | buriti dos lopes
# Processing Record 47 of Set 6 | shasta lake
# Processing Record 48 of Set 6 | sambava
# Processing Record 49 of Set 6 | three hills
# Processing Record 50 of Set 6 | asosa
# Processing Record 1 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 7 | tahoua
# Processing Record 3 of Set 7 | linhares
# Processing Record 4 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 7 | verkhnyaya inta
# Processing Record 7 of Set 7 | kilemary
# Processing Record 8 of Set 7 | pravia
# Processing Record 9 of Set 7 | tres arroyos
# Processing Record 10 of Set 7 | kushmurun
# Processing Record 11 of Set 7 | ahipara
# Processing Record 12 of Set 7 | batticaloa
# Processing Record 13 of Set 7 | kasongo-lunda
# Processing Record 14 of Set 7 | aranda de duero
# Processing Record 15 of Set 7 | beidao
# Processing Record 16 of Set 7 | khorixas
# Processing Record 17 of Set 7 | waipawa
# Processing Record 18 of Set 7 | alamosa
# Processing Record 19 of Set 7 | venice
# Processing Record 20 of Set 7 | bafata
# Processing Record 21 of Set 7 | pacific grove
# Processing Record 22 of Set 7 | ostrovnoy
# Processing Record 23 of Set 7 | ondjiva
# Processing Record 24 of Set 7 | lima
# Processing Record 25 of Set 7 | lososina
# Processing Record 26 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 7 | aklavik
# Processing Record 28 of Set 7 | kholodnyy
# Processing Record 29 of Set 7 | westport
# Processing Record 30 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 31 of Set 7 | bereda
# Processing Record 32 of Set 7 | burla
# Processing Record 33 of Set 7 | phangnga
# Processing Record 34 of Set 7 | porto nacional
# Processing Record 35 of Set 7 | nago
# Processing Record 36 of Set 7 | bhadrapur
# Processing Record 37 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 7 | gdansk
# Processing Record 39 of Set 7 | powell
# Processing Record 40 of Set 7 | aykhal
# Processing Record 41 of Set 7 | vila franca do campo
# Processing Record 42 of Set 7 | new norfolk
# Processing Record 43 of Set 7 | korla
# Processing Record 44 of Set 7 | sagua la grande
# Processing Record 45 of Set 7 | rogers
# Processing Record 46 of Set 7 | remedios
# Processing Record 47 of Set 7 | kununurra
# Processing Record 48 of Set 7 | methoni
# Processing Record 49 of Set 7 | hirara
# Processing Record 50 of Set 7 | puksoozero
# Processing Record 1 of Set 8 | marsh harbour
# Processing Record 2 of Set 8 | aguimes
# Processing Record 3 of Set 8 | sitka
# Processing Record 4 of Set 8 | ola
# Processing Record 5 of Set 8 | torbay
# Processing Record 6 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 8 | mana
# Processing Record 8 of Set 8 | kendari
# Processing Record 9 of Set 8 | bohodukhiv
# Processing Record 10 of Set 8 | santa catarina de tepehuanes
# Processing Record 11 of Set 8 | severo-kurilsk
# Processing Record 12 of Set 8 | sirjan
# Processing Record 13 of Set 8 | kodinsk
# Processing Record 14 of Set 8 | sayat
# Processing Record 15 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 8 | ginir
# Processing Record 17 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 18 of Set 8 | havelock
# Processing Record 19 of Set 8 | turbat
# Processing Record 20 of Set 8 | cedar city
# Processing Record 21 of Set 8 | dahuk
# Processing Record 22 of Set 8 | mora
# Processing Record 23 of Set 8 | alofi
# Processing Record 24 of Set 8 | sesheke
# Processing Record 25 of Set 8 | moose factory
# Processing Record 26 of Set 8 | shangqiu
# Processing Record 27 of Set 8 | tiksi
# Processing Record 28 of Set 8 | farsund
# Processing Record 29 of Set 8 | broken hill
# Processing Record 30 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 31 of Set 8 | bousse
# Processing Record 32 of Set 8 | san javier
# Processing Record 33 of Set 8 | vestmannaeyjar
# Processing Record 34 of Set 8 | nome
# Processing Record 35 of Set 8 | aksu
# Processing Record 36 of Set 8 | jinchang
# Processing Record 37 of Set 8 | kaitangata
# Processing Record 38 of Set 8 | cilegon
# Processing Record 39 of Set 8 | narsaq
# Processing Record 40 of Set 8 | kahului
# Processing Record 41 of Set 8 | ruiz
# Processing Record 42 of Set 8 | lagoa da prata
# Processing Record 43 of Set 8 | indiaroba
# Processing Record 44 of Set 8 | puerto asis
# Processing Record 45 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 8 | taitung
# Processing Record 47 of Set 8 | kyabe
# Processing Record 48 of Set 8 | araguaina
# Processing Record 49 of Set 8 | xining
# Processing Record 50 of Set 8 | coos bay
# Processing Record 1 of Set 9 | dolores
# Processing Record 2 of Set 9 | sao miguel do araguaia
# Processing Record 3 of Set 9 | hambantota
# Processing Record 4 of Set 9 | ocosingo
# Processing Record 5 of Set 9 | eirunepe
# Processing Record 6 of Set 9 | dikson
# Processing Record 7 of Set 9 | moerai
# Processing Record 8 of Set 9 | jay
# Processing Record 9 of Set 9 | katsuura
# Processing Record 10 of Set 9 | kargasok
# Processing Record 11 of Set 9 | fenoarivo
# Processing Record 12 of Set 9 | parakou
# Processing Record 13 of Set 9 | lasa
# Processing Record 14 of Set 9 | kretinga
# Processing Record 15 of Set 9 | surt
# Processing Record 16 of Set 9 | yatou
# Processing Record 17 of Set 9 | antalaha
# Processing Record 18 of Set 9 | laguna
# Processing Record 19 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 9 | carutapera
# Processing Record 21 of Set 9 | kieta
# Processing Record 22 of Set 9 | leshukonskoye
# Processing Record 23 of Set 9 | lisakovsk
# Processing Record 24 of Set 9 | lebedinyy
# Processing Record 25 of Set 9 | palmer
# Processing Record 26 of Set 9 | derazhnya
# Processing Record 27 of Set 9 | gao
# Processing Record 28 of Set 9 | yeppoon
# Processing Record 29 of Set 9 | nalut
# Processing Record 30 of Set 9 | olafsvik
# Processing Record 31 of Set 9 | akola
# Processing Record 32 of Set 9 | san policarpo
# Processing Record 33 of Set 9 | kualakapuas
# Processing Record 34 of Set 9 | ouallam
# Processing Record 35 of Set 9 | vila velha
# Processing Record 36 of Set 9 | buala
# Processing Record 37 of Set 9 | iisalmi
# Processing Record 38 of Set 9 | lorengau
# Processing Record 39 of Set 9 | tuatapere
# Processing Record 40 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 9 | tonosho
# Processing Record 42 of Set 9 | magadan
# Processing Record 43 of Set 9 | gizo
# Processing Record 44 of Set 9 | nyurba
# Processing Record 45 of Set 9 | acari
# Processing Record 46 of Set 9 | preobrazheniye
# Processing Record 47 of Set 9 | zyryanovsk
# Processing Record 48 of Set 9 | santa isabel do rio negro
# Processing Record 49 of Set 9 | benghazi
# Processing Record 50 of Set 9 | haines junction
# Processing Record 1 of Set 10 | beyneu
# Processing Record 2 of Set 10 | mogok
# Processing Record 3 of Set 10 | thinadhoo
# Processing Record 4 of Set 10 | mae sai
# Processing Record 5 of Set 10 | vao
# Processing Record 6 of Set 10 | pilar
# Processing Record 7 of Set 10 | ilulissat
# Processing Record 8 of Set 10 | buraydah
# Processing Record 9 of Set 10 | opuwo
# Processing Record 10 of Set 10 | druzhba
# Processing Record 11 of Set 10 | marienburg
# Processing Record 12 of Set 10 | yashkul
# Processing Record 13 of Set 10 | hamburg
# Processing Record 14 of Set 10 | nanortalik
# Processing Record 15 of Set 10 | los llanos de aridane
# Processing Record 16 of Set 10 | belyy yar
# Processing Record 17 of Set 10 | touros
# Processing Record 18 of Set 10 | cockburn town
# Processing Record 19 of Set 10 | leningradskiy
# Processing Record 20 of Set 10 | iqaluit
# Processing Record 21 of Set 10 | pontecorvo
# Processing Record 22 of Set 10 | srednekolymsk
# Processing Record 23 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 10 | ratnagiri
# Processing Record 25 of Set 10 | batsfjord
# Processing Record 26 of Set 10 | east haddam
# Processing Record 27 of Set 10 | gigmoto
# Processing Record 28 of Set 10 | constitucion
# Processing Record 29 of Set 10 | qasigiannguit
# Processing Record 30 of Set 10 | gondanglegi
# Processing Record 31 of Set 10 | teguise
# Processing Record 32 of Set 10 | alexandria
# Processing Record 33 of Set 10 | sao joao da barra
# Processing Record 34 of Set 10 | guiyang
# Processing Record 35 of Set 10 | lagunas
# Processing Record 36 of Set 10 | sekoma
# Processing Record 37 of Set 10 | dandong
# Processing Record 38 of Set 10 | shakhrinau
# City not found. Skipping...
# Processing Record 39 of Set 10 | raudeberg
# Processing Record 40 of Set 10 | birao
# Processing Record 41 of Set 10 | sampit
# Processing Record 42 of Set 10 | teguldet
# Processing Record 43 of Set 10 | torit
# Processing Record 44 of Set 10 | yulara
# Processing Record 45 of Set 10 | mayo
# Processing Record 46 of Set 10 | akyab
# Processing Record 47 of Set 10 | manoel urbano
# Processing Record 48 of Set 10 | carbondale
# Processing Record 49 of Set 10 | sena madureira
# Processing Record 50 of Set 10 | lazurne
# Processing Record 1 of Set 11 | leh
# Processing Record 2 of Set 11 | altamont
# Processing Record 3 of Set 11 | tambopata
# Processing Record 4 of Set 11 | vrangel
# Processing Record 5 of Set 11 | arica
# Processing Record 6 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 11 | churapcha
# Processing Record 8 of Set 11 | jalu
# Processing Record 9 of Set 11 | hare bay
# Processing Record 10 of Set 11 | miami shores
# Processing Record 11 of Set 11 | mehamn
# Processing Record 12 of Set 11 | ternate
# Processing Record 13 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 11 | raga
# Processing Record 15 of Set 11 | upington
# Processing Record 16 of Set 11 | port hedland
# Processing Record 17 of Set 11 | axim
# Processing Record 18 of Set 11 | traralgon
# Processing Record 19 of Set 11 | poso
# Processing Record 20 of Set 11 | siverek
# Processing Record 21 of Set 11 | dingle
# Processing Record 22 of Set 11 | altay
# Processing Record 23 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 11 | veranopolis
# Processing Record 25 of Set 11 | tiznit
# Processing Record 26 of Set 11 | oktyabrskiy
# Processing Record 27 of Set 11 | lazaro cardenas
# Processing Record 28 of Set 11 | orlik
# Processing Record 29 of Set 11 | ginda
# Processing Record 30 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 11 | hamilton
# Processing Record 33 of Set 11 | gornyy
# Processing Record 34 of Set 11 | atherton
# Processing Record 35 of Set 11 | wagar
# Processing Record 36 of Set 11 | praia da vitoria
# Processing Record 37 of Set 11 | lubyany
# Processing Record 38 of Set 11 | borogontsy
# Processing Record 39 of Set 11 | sijunjung
# Processing Record 40 of Set 11 | hervey bay
# Processing Record 41 of Set 11 | la ronge
# Processing Record 42 of Set 11 | adeje
# Processing Record 43 of Set 11 | qaqortoq
# Processing Record 44 of Set 11 | zhob
# Processing Record 45 of Set 11 | cabedelo
# Processing Record 46 of Set 11 | nador
# Processing Record 47 of Set 11 | rio gallegos
# Processing Record 48 of Set 11 | solnechnyy
# Processing Record 49 of Set 11 | dosso
# Processing Record 50 of Set 11 | itoman
# Processing Record 1 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 2 of Set 12 | dwarka
# Processing Record 3 of Set 12 | sfantu gheorghe
# Processing Record 4 of Set 12 | heilbron
# Processing Record 5 of Set 12 | iracoubo
# Processing Record 6 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 12 | kodiak
# Processing Record 8 of Set 12 | kampot
# Processing Record 9 of Set 12 | flinders
# Processing Record 10 of Set 12 | rosarito
# Processing Record 11 of Set 12 | zirandaro
# Processing Record 12 of Set 12 | varkkallai
# Processing Record 13 of Set 12 | la palma
# Processing Record 14 of Set 12 | cayenne
# Processing Record 15 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 16 of Set 12 | selma
# Processing Record 17 of Set 12 | playa del carmen
# Processing Record 18 of Set 12 | emerald
# Processing Record 19 of Set 12 | kungurtug
# Processing Record 20 of Set 12 | oxapampa
# Processing Record 21 of Set 12 | ballina
# Processing Record 22 of Set 12 | waycross
# Processing Record 23 of Set 12 | emmett
# Processing Record 24 of Set 12 | havoysund
# Processing Record 25 of Set 12 | babu
# Processing Record 26 of Set 12 | mangrol
# Processing Record 27 of Set 12 | coracao de jesus
# Processing Record 28 of Set 12 | san jose de guanipa
# Processing Record 29 of Set 12 | colares
# Processing Record 30 of Set 12 | helena
# Processing Record 31 of Set 12 | coquimbo
# Processing Record 32 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 12 | ahome
# Processing Record 34 of Set 12 | jelgava
# Processing Record 35 of Set 12 | takoradi
# Processing Record 36 of Set 12 | faya
# Processing Record 37 of Set 12 | saint-augustin
# Processing Record 38 of Set 12 | dubbo
# Processing Record 39 of Set 12 | samfya
# Processing Record 40 of Set 12 | avera
# Processing Record 41 of Set 12 | nagar karnul
# Processing Record 42 of Set 12 | xiuyan
# Processing Record 43 of Set 12 | road town
# Processing Record 44 of Set 12 | kuusamo
# Processing Record 45 of Set 12 | mingyue
# Processing Record 46 of Set 12 | irara
# Processing Record 47 of Set 12 | manuk mangkaw
# Processing Record 48 of Set 12 | hokitika
# Processing Record 49 of Set 12 | mafeteng
# Processing Record 50 of Set 12 | mahebourg
# Processing Record 1 of Set 13 | nioki
# Processing Record 2 of Set 13 | tungor
# Processing Record 3 of Set 13 | georgiyevka
# Processing Record 4 of Set 13 | adrar
# Processing Record 5 of Set 13 | llanes
# Processing Record 6 of Set 13 | mandali
# Processing Record 7 of Set 13 | del rio
# Processing Record 8 of Set 13 | kuytun
# Processing Record 9 of Set 13 | roma
# Processing Record 10 of Set 13 | kapuskasing
# Processing Record 11 of Set 13 | indramayu
# Processing Record 12 of Set 13 | choya
# Processing Record 13 of Set 13 | calais
# Processing Record 14 of Set 13 | shenjiamen
# Processing Record 15 of Set 13 | pattaya
# Processing Record 16 of Set 13 | christiana
# Processing Record 17 of Set 13 | puerto leguizamo
# Processing Record 18 of Set 13 | vydrino
# Processing Record 19 of Set 13 | naze
# Processing Record 20 of Set 13 | talnakh
# Processing Record 21 of Set 13 | nagato
# Processing Record 22 of Set 13 | wahlern
# Processing Record 23 of Set 13 | makakilo city
# Processing Record 24 of Set 13 | krasnoborsk
# Processing Record 25 of Set 13 | novobohdanivka
# Processing Record 26 of Set 13 | kailua
# Processing Record 27 of Set 13 | bideford
# Processing Record 28 of Set 13 | tynda
# Processing Record 29 of Set 13 | anloga
# Processing Record 30 of Set 13 | stornoway
# Processing Record 31 of Set 13 | sompeta
# Processing Record 32 of Set 13 | menongue
# Processing Record 33 of Set 13 | lakes entrance
# Processing Record 34 of Set 13 | ouadda
# Processing Record 35 of Set 13 | bonga
# Processing Record 36 of Set 13 | danao
# Processing Record 37 of Set 13 | chabahar
# Processing Record 38 of Set 13 | tayzhina
# Processing Record 39 of Set 13 | shache
# Processing Record 40 of Set 13 | zeljezno polje
# Processing Record 41 of Set 13 | turkmenabat
# Processing Record 42 of Set 13 | oktyabrskoye
# Processing Record 43 of Set 13 | piquete
# Processing Record 44 of Set 13 | dingli
# Processing Record 45 of Set 13 | samarai
# Processing Record 46 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 47 of Set 13 | basoko
# Processing Record 48 of Set 13 | salamiyah
# Processing Record 49 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 50 of Set 13 | southbridge
# Processing Record 1 of Set 14 | barra do corda
# Processing Record 2 of Set 14 | nirmal
# Processing Record 3 of Set 14 | north bend
# Processing Record 4 of Set 14 | bealanana
# Processing Record 5 of Set 14 | lai
# Processing Record 6 of Set 14 | ust-omchug
# Processing Record 7 of Set 14 | coruripe
# Processing Record 8 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 9 of Set 14 | atar
# Processing Record 10 of Set 14 | tutoia
# Processing Record 11 of Set 14 | qixingtai
# Processing Record 12 of Set 14 | podor
# Processing Record 13 of Set 14 | gryazi
# Processing Record 14 of Set 14 | natal
# Processing Record 15 of Set 14 | luderitz
# Processing Record 16 of Set 14 | nishihara
# Processing Record 17 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 18 of Set 14 | lata
# Processing Record 19 of Set 14 | kapoeta
# Processing Record 20 of Set 14 | bulungu
# Processing Record 21 of Set 14 | verkh-suetka
# Processing Record 22 of Set 14 | alice town
# Processing Record 23 of Set 14 | fantanele
# Processing Record 24 of Set 14 | fairbanks
# Processing Record 25 of Set 14 | tual
# Processing Record 26 of Set 14 | cleethorpes
# Processing Record 27 of Set 14 | chapais
# Processing Record 28 of Set 14 | caarapo
# Processing Record 29 of Set 14 | katherine
# Processing Record 30 of Set 14 | kalmunai
# Processing Record 31 of Set 14 | smithers
# Processing Record 32 of Set 14 | parana
# Processing Record 33 of Set 14 | wallasey
# Processing Record 34 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 35 of Set 14 | batagay-alyta
# Processing Record 36 of Set 14 | craigieburn
# Processing Record 37 of Set 14 | cody
# Processing Record 38 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 14 | shingu
# Processing Record 40 of Set 14 | palana
# Processing Record 41 of Set 14 | yambio
# Processing Record 42 of Set 14 | northam
# Processing Record 43 of Set 14 | zonhoven
# Processing Record 44 of Set 14 | rio verde de mato grosso
# Processing Record 45 of Set 14 | lokosovo
# Processing Record 46 of Set 14 | jega
# Processing Record 47 of Set 14 | charters towers
# Processing Record 48 of Set 14 | levelland
# Processing Record 49 of Set 14 | padang
# Processing Record 50 of Set 14 | sonda
# Processing Record 1 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 15 | san jeronimo
# Processing Record 3 of Set 15 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 4 of Set 15 | asino
# Processing Record 5 of Set 15 | vardo
# Processing Record 6 of Set 15 | camopi
# Processing Record 7 of Set 15 | alta floresta
# Processing Record 8 of Set 15 | oum hadjer
# Processing Record 9 of Set 15 | luancheng
# Processing Record 10 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 15 | maceio
# Processing Record 12 of Set 15 | beringovskiy
# Processing Record 13 of Set 15 | thatta
# Processing Record 14 of Set 15 | prado
# Processing Record 15 of Set 15 | kjollefjord
# Processing Record 16 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 18 of Set 15 | cururupu
# Processing Record 19 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 21 of Set 15 | never
# Processing Record 22 of Set 15 | saint-georges
# Processing Record 23 of Set 15 | berlevag
# Processing Record 24 of Set 15 | longyan
# Processing Record 25 of Set 15 | mahuva
# Processing Record 26 of Set 15 | moissac
# Processing Record 27 of Set 15 | chukhloma
# Processing Record 28 of Set 15 | ulaanbaatar
# Processing Record 29 of Set 15 | harper
# Processing Record 30 of Set 15 | bara
# Processing Record 31 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 15 | hongjiang
# Processing Record 33 of Set 15 | basco
# Processing Record 34 of Set 15 | darhan
# Processing Record 35 of Set 15 | saint-louis
# Processing Record 36 of Set 15 | aranos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0                tasiilaq      GL  65.6145  -37.6368     -2.00        59
# 1                 husavik      IS  66.0449  -17.3389     22.91        65
# 2  santa cruz de la palma      ES  28.6835  -17.7642     73.13        64
# 3                  nemuro      JP  43.3236  145.5750     19.94        78
# 4                 shimoda      JP  34.6667  138.9500     37.11        95
#
#    Cloudiness  Wind Speed Current Description
# 0          74       11.32       broken clouds
# 1         100       18.28     overcast clouds
# 2           0        1.14           clear sky
# 3           9        7.02           clear sky
# 4         100       18.16       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
